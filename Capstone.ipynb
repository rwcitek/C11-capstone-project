# %% [markdown]
# <a href="https://colab.research.google.com/github/brooksburkhead/capstone-project/blob/main/Capstone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Science Problem Solving Template

# %% [markdown]
# ## Problem Statement
# - Define the problem and its objectives.
# - Understand the domain and context.

# %% [markdown]
# ## Data Collection
# - Identify data sources.
# - Gather the necessary data.

# %% [markdown]
# ## Data Loading
# - Load data into your analysis environment.

# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
file_path = '/content/drive/MyDrive/raw_ebird_data_sample.txt' #mounted my drive to notebook, loaded data from drive
df = pd.read_csv(file_path, delimiter = '\t', header = None)
df
# Out:
#                                                    0   \
# 0       URN:CornellLabOfOrnithology:EBIRD:OBS21257524
# 1       URN:CornellLabOfOrnithology:EBIRD:OBS21257521
# 2      URN:CornellLabOfOrnithology:EBIRD:OBS377845261
# 3       URN:CornellLabOfOrnithology:EBIRD:OBS27061959
# 4      URN:CornellLabOfOrnithology:EBIRD:OBS815681738
# ...                                               ...
# 99995   URN:CornellLabOfOrnithology:EBIRD:OBS28062463
# 99996   URN:CornellLabOfOrnithology:EBIRD:OBS28062895
# 99997   URN:CornellLabOfOrnithology:EBIRD:OBS28057391
# 99998   URN:CornellLabOfOrnithology:EBIRD:OBS28056780
# 99999   URN:CornellLabOfOrnithology:EBIRD:OBS28062591
#
#                                1      2        3                 4   \
# 0      2022-12-21 15:09:49.594028    505  species  avibase-85625D75
# 1      2022-12-21 15:09:49.594028  23564  species  avibase-94A1C447
# 2             2018-05-20 17:56:41  33451  species  avibase-67B455A7
# ...

# %% [markdown]
# ### Data looks okay so far... only missing column names

# %%
with open("/content/drive/MyDrive/headers.txt", "r") as headers:
	lines = headers.readlines()
lines
# Out:
# ['GLOBAL UNIQUE IDENTIFIER\tLAST EDITED DATE\tTAXONOMIC ORDER\tCATEGORY\tTAXON CONCEPT ID\tCOMMON NAME\tSCIENTIFIC NAME\tSUBSPECIES COMMON NAME\tSUBSPECIES SCIENTIFIC NAME\tEXOTIC CODE\tOBSERVATION COUNT\tBREEDING CODE\tBREEDING CATEGORY\tBEHAVIOR CODE\tAGE/SEX\tCOUNTRY\tCOUNTRY CODE\tSTATE\tSTATE CODE\tCOUNTY\tCOUNTY CODE\tIBA CODE\tBCR CODE\tUSFWS CODE\tATLAS BLOCK\tLOCALITY\tLOCALITY ID\tLOCALITY TYPE\tLATITUDE\tLONGITUDE\tOBSERVATION DATE\tTIME OBSERVATIONS STARTED\tOBSERVER ID\tSAMPLING EVENT IDENTIFIER\tPROTOCOL TYPE\tPROTOCOL CODE\tPROJECT CODE\tDURATION MINUTES\tEFFORT DISTANCE KM\tEFFORT AREA HA\tNUMBER OBSERVERS\tALL SPECIES REPORTED\tGROUP IDENTIFIER\tHAS MEDIA\tAPPROVED\tREVIEWED\tREASON\tTRIP COMMENTS\tSPECIES COMMENTS\n']

# %% [markdown]
# We'll quickly clean up this file so that we can use these are our column names

# %%
col_names = lines[0].strip().split('\t')
col_names
# Out:
# ['GLOBAL UNIQUE IDENTIFIER',
#  'LAST EDITED DATE',
#  'TAXONOMIC ORDER',
#  'CATEGORY',
#  'TAXON CONCEPT ID',
#  'COMMON NAME',
#  'SCIENTIFIC NAME',
#  'SUBSPECIES COMMON NAME',
#  'SUBSPECIES SCIENTIFIC NAME',
#  'EXOTIC CODE',
#  'OBSERVATION COUNT',
#  'BREEDING CODE',
#  'BREEDING CATEGORY',
#  'BEHAVIOR CODE',
#  'AGE/SEX',
#  'COUNTRY',
#  'COUNTRY CODE',
#  'STATE',
#  'STATE CODE',
#  'COUNTY',
#  'COUNTY CODE',
#  'IBA CODE',
#  'BCR CODE',
#  'USFWS CODE',
#  'ATLAS BLOCK',
#  'LOCALITY',
#  'LOCALITY ID',
#  'LOCALITY TYPE',
#  'LATITUDE',
#  'LONGITUDE',
#  'OBSERVATION DATE',
#  'TIME OBSERVATIONS STARTED',
#  'OBSERVER ID',
#  'SAMPLING EVENT IDENTIFIER',
#  'PROTOCOL TYPE',
#  'PROTOCOL CODE',
#  'PROJECT CODE',
#  'DURATION MINUTES',
#  'EFFORT DISTANCE KM',
#  'EFFORT AREA HA',
#  'NUMBER OBSERVERS',
#  'ALL SPECIES REPORTED',
#  'GROUP IDENTIFIER',
#  'HAS MEDIA',
#  'APPROVED',
#  'REVIEWED',
#  'REASON',
#  'TRIP COMMENTS',
#  'SPECIES COMMENTS']

# %%
df.columns = col_names
df
# Out:
#                              GLOBAL UNIQUE IDENTIFIER  \
# 0       URN:CornellLabOfOrnithology:EBIRD:OBS21257524
# 1       URN:CornellLabOfOrnithology:EBIRD:OBS21257521
# 2      URN:CornellLabOfOrnithology:EBIRD:OBS377845261
# 3       URN:CornellLabOfOrnithology:EBIRD:OBS27061959
# 4      URN:CornellLabOfOrnithology:EBIRD:OBS815681738
# ...                                               ...
# 99995   URN:CornellLabOfOrnithology:EBIRD:OBS28062463
# 99996   URN:CornellLabOfOrnithology:EBIRD:OBS28062895
# 99997   URN:CornellLabOfOrnithology:EBIRD:OBS28057391
# 99998   URN:CornellLabOfOrnithology:EBIRD:OBS28056780
# 99999   URN:CornellLabOfOrnithology:EBIRD:OBS28062591
#
#                  LAST EDITED DATE  TAXONOMIC ORDER CATEGORY  TAXON CONCEPT ID  \
# 0      2022-12-21 15:09:49.594028              505  species  avibase-85625D75
# 1      2022-12-21 15:09:49.594028            23564  species  avibase-94A1C447
# 2             2018-05-20 17:56:41            33451  species  avibase-67B455A7
# ...

# %% [markdown]
# ## Data Exploration (EDA)
# - Explore data structure and content.
# - Check data types, missing values, and summary statistics.
# - Visualize data for patterns and relationships.

# %%
# !curl -s -O 'https://raw.githubusercontent.com/brooksburkhead/toolbox/main/functions.py' #load functions from my Data Science 'toolbox'

# %%
import functions as fn

# %%
fn.get_metadata(df)
# Out:
#                            Data Types    Memory    Rows   Nulls   Null %  \
# GLOBAL UNIQUE IDENTIFIER       object  10283722  100000       0    0.000
# LAST EDITED DATE               object   8119819  100000       0    0.000
# TAXONOMIC ORDER                 int64    800000  100000       0    0.000
# CATEGORY                       object   6386263  100000       0    0.000
# TAXON CONCEPT ID               object   7300000  100000       0    0.000
# COMMON NAME                    object   7256388  100000       0    0.000
# SCIENTIFIC NAME                object   7478066  100000       0    0.000
# SUBSPECIES COMMON NAME         object   3432610  100000   95761   95.761
# SUBSPECIES SCIENTIFIC NAME     object   3435524  100000   95761   95.761
# EXOTIC CODE                    object   3278702  100000   96973   96.973
# OBSERVATION COUNT              object   5812465  100000       0    0.000
# BREEDING CODE                  object   3238247  100000   98582   98.582
# ...

# %%
df['STATE'].value_counts()
# Out:
# New Mexico    99988
# Arizona           7
# Texas             5
# Name: STATE, dtype: int64

# %%
filter = (df['STATE'] == 'Arizona') | (df['STATE'] == 'Texas')

# %%
filter2 = df['STATE CODE'] != 'US-NM'

# %%
df[filter2]['STATE CODE'].value_counts()
# Out:
# US-AZ    7
# US-TX    5
# Name: STATE CODE, dtype: int64

# %%
df[filter2].index
# Out:
# Int64Index([27116, 44397, 52425, 69946, 79226, 79227, 79228, 87341, 87342, 87343, 96621, 96622], dtype='int64')

# %%
df.drop(index = df[filter2].index, inplace = True )

# %%
fn.get_metadata(df)
# Out:
#                            Data Types    Memory   Rows  Nulls      Null %  count  unique                                           mode   freq          mean           std         min        25%     median         75%         max
# GLOBAL UNIQUE IDENTIFIER       object  10282479  99988      0    0.000000  99988   99988  URN:CornellLabOfOrnithology:EBIRD:OBS21257524      1           NaN           NaN         NaN        NaN        NaN         NaN         NaN
# LAST EDITED DATE               object   8118865  99988      0    0.000000  99988   11347                     2022-12-23 08:35:31.382878   1748           NaN           NaN         NaN        NaN        NaN         NaN         NaN
# TAXONOMIC ORDER                 int64    799904  99988      0    0.000000  99988     611                                            NaN    NaN  18012.089751  12361.498392       230.0     6045.0    20571.0     31945.0     35132.0
# ...

# %%
df['BEHAVIOR CODE'].value_counts().plot.bar() ;
# Out:
# <Axes: >

# %% [markdown]
# ##Data Cleaning
#
# - Handle missing data.
# - Remove duplicates.
# - Correct errors, inconsistencies, and outliers.
# - Ensure data format and types.

# %% [markdown]
# ## Data Pre-processing
# - Feature selection.
# - Feature engineering.
# - Scale or normalize numerical features.
# - Encode categorical variables.
# - Handle class imbalances.

# %% [markdown]
# ## Data Splitting
# - Divide the dataset into training, validation, and test sets.
# - Ensure random or stratified splits.

# %% [markdown]
# ## Model Selection
# - Choose machine learning algorithms.
# - Compare different models.
# - Tune hyperparameters.

# %% [markdown]
# ## Model Training
# - Train models on the training data.
# - Monitor training progress.

# %% [markdown]
# ## Model Evaluation
# - Evaluate model performance using appropriate metrics.
# - Visualize performance with relevant plots.

# %% [markdown]
# ## Model Interpretation
# - Interpret model results.
# - Explain model decisions.

# %% [markdown]
# ## Reporting and Communication
# - Create a report or presentation summarizing the project.
# - Communicate findings to stakeholders.

# %% [markdown]
# ## Documentation and Reproducibility
# - Document your work.
# - Ensure reproducibility.

# %% [markdown]
# ## Iteration and Improvement
# - Continuously improve the model based on feedback and new data.
